# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/NUMPY-PRACTICE/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *NUMPY*

# %%
import numpy as np

# %% [markdown]
# # **Creating Array from List**

# %%
arr1 = np.array([1, 2, 3, 4, 5])
print(" 1D array :", arr1)

arr2 = np.array([[1, 2, 3],[ 4, 5, 6]])
print(" 2D array :", arr2)
# Out:
#  1D array : [1 2 3 4 5]
#  2D array : [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## **List Vs Numpy array**

# %%
py_list = [1, 2, 3]
print("Python list nultiplication" , py_list*2)

np_array = np.array([1, 2, 3])
print("Numpy array multiplication" , np_array*2)
# Out:
# Python list nultiplication [1, 2, 3, 1, 2, 3]
# Numpy array multiplication [2 4 6]
